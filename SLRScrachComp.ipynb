# %% [markdown]
# <a href="https://colab.research.google.com/github/bountyhunter12/ML/blob/main/SLRScrachComp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement 1.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0:1].values
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([[6.89],
#        [5.12],
#        [7.82],
#        [7.42],
#        [6.94],
#        [7.89],
#        [6.73],
#        [6.75],
#        [6.09],
#        [8.31],
#        [5.32],
#        [6.61],
#        [8.94],
#        [6.93],
#        [7.73],
#        [7.25],
#        [6.84],
#        [5.38],
#        [6.94],
#        [7.48],
#        [7.28],
#        [6.85],
#        [6.14],
#        [6.19],
#        [6.53],
#        [7.28],
#        [8.31],
#        [5.42],
#        [5.94],
#        [7.15],
#        [7.36],
#        [8.1 ],
#        [6.96],
#        [6.35],
#        [7.34],
#        [6.87],
#        [5.99],
#        [5.9 ],
#        [8.62],
#        [7.43],
#        [9.38],
#        [6.89],
#        [5.95],
#        [7.66],
#        [5.09],
#        [7.87],
#        [6.07],
#        [5.84],
#        [8.63],
#        [8.87],
#        [9.58],
#        [9.26],
#        [8.37],
#        [6.47],
#        [6.86],
#        [8.2 ],
#        [5.84],
#        [6.6 ],
# ...

# %%
X.shape
# Out:
# (200, 1)
# (200, 1)

# %%
y
# Out:
# array([3.26, 1.98, 3.25, 3.67, 3.57, 2.99, 2.6 , 2.48, 2.31, 3.51, 1.86,
#        2.6 , 3.65, 2.89, 3.42, 3.23, 2.35, 2.09, 2.98, 2.83, 3.16, 2.93,
#        2.3 , 2.48, 2.71, 3.65, 3.42, 2.16, 2.24, 3.49, 3.26, 3.89, 3.08,
#        2.73, 3.42, 2.87, 2.84, 2.43, 4.36, 3.33, 4.02, 2.7 , 2.54, 2.76,
#        1.86, 3.58, 2.26, 3.26, 4.09, 4.62, 4.43, 3.79, 4.11, 2.61, 3.09,
#        3.39, 2.74, 1.94, 3.09, 3.31, 2.19, 1.61, 2.09, 4.25, 2.92, 3.81,
#        1.63, 2.89, 2.99, 2.94, 2.35, 3.34, 3.62, 4.03, 3.44, 3.28, 3.15,
#        4.6 , 2.21, 3.  , 3.44, 2.2 , 2.17, 3.49, 1.53, 1.48, 2.77, 3.55,
#        1.48, 2.72, 2.66, 2.14, 4.  , 3.08, 2.42, 2.79, 2.61, 2.84, 3.83,
#        3.24, 4.14, 3.52, 1.37, 3.  , 3.74, 2.82, 2.19, 2.59, 3.54, 4.06,
#        3.76, 2.25, 4.1 , 2.37, 1.87, 4.21, 3.33, 2.99, 2.88, 2.65, 1.73,
#        3.02, 2.01, 2.3 , 2.31, 3.16, 2.6 , 3.11, 3.34, 3.12, 2.49, 2.01,
#        2.48, 2.58, 2.83, 2.6 , 2.1 , 3.13, 3.89, 2.4 , 3.15, 3.18, 3.04,
# ...

# %%
y.shape
# Out:
# (200,)
# (200,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160, 1)
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()
# LinearRegression()

# %%
y_pre = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
print("R2",r2_score(y_test,y_pre))
# Out:
# R2 0.780730147510384
# R2 0.780730147510384

# %%
class MLR:

  def __init__(self):
      self.m = None
      self.b = None

  def fit(self,X_train,y_train):

      num = 0
      den = 0

      for i in range(X_train.shape[0]):

          num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
          den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))

      self.m = num/den
      self.b = y_train.mean() - (self.m * X_train.mean())
      print(self.m)
      print(self.b)

  def predict(self,X_test):

      print(X_test)

      return self.m * X_test + self.b

# %%
lr = MLR()

# %%
lr.fit(X_train,y_train)
# Out:
# [0.55795197]
# [-0.89611192]
# [0.55795197]
# [-0.89611192]

# %%
X_train
# Out:
# array([[7.14],
#        [8.93],
#        [5.42],
#        [5.1 ],
#        [7.77],
#        [6.76],
#        [6.89],
#        [6.68],
#        [7.91],
#        [7.89],
#        [8.71],
#        [7.95],
#        [6.61],
#        [6.26],
#        [6.53],
#        [6.42],
#        [5.11],
#        [6.09],
#        [6.93],
#        [7.04],
#        [5.94],
#        [6.05],
#        [5.83],
#        [5.95],
#        [9.31],
#        [5.58],
#        [7.88],
#        [6.13],
#        [7.76],
#        [4.85],
#        [6.19],
#        [8.6 ],
#        [6.07],
#        [7.18],
#        [5.12],
#        [7.39],
#        [8.25],
#        [8.28],
#        [7.13],
#        [7.35],
#        [5.66],
#        [5.99],
#        [8.01],
#        [7.14],
#        [6.34],
#        [6.89],
#        [5.42],
#        [6.47],
#        [7.69],
#        [7.4 ],
#        [7.28],
#        [5.95],
#        [7.38],
#        [6.93],
#        [8.99],
#        [7.36],
#        [7.08],
#        [5.38],
# ...

# %%
y_pre = lr.predict(X_test)
# Out:
# [[8.58]
#  [7.15]
#  [5.88]
#  [6.22]
#  [4.57]
#  [4.79]
#  [5.32]
#  [6.86]
#  [8.35]
#  [6.87]
#  [8.94]
#  [7.9 ]
#  [6.93]
#  [5.91]
#  [7.32]
#  [7.82]
#  [5.09]
#  [7.42]
#  [6.94]
#  [7.73]
#  [6.19]
#  [7.28]
#  [6.73]
#  [7.2 ]
#  [8.21]
#  [6.75]
#  [7.87]
#  [7.6 ]
#  [8.63]
#  [5.12]
#  [8.15]
#  [7.36]
#  [8.31]
#  [6.6 ]
#  [6.59]
#  [7.47]
#  [7.93]
#  [6.29]
#  [6.37]
#  [6.47]]
# [[8.58]
#  [7.15]
#  [5.88]
#  [6.22]
#  [4.57]
#  [4.79]
#  [5.32]
#  [6.86]
#  [8.35]
#  [6.87]
#  [8.94]
#  [7.9 ]
#  [6.93]
#  [5.91]
#  [7.32]
#  [7.82]
#  [5.09]
#  [7.42]
#  [6.94]
#  [7.73]
#  [6.19]
#  [7.28]
#  [6.73]
#  [7.2 ]
#  [8.21]
#  [6.75]
#  [7.87]
#  [7.6 ]
#  [8.63]
#  [5.12]
#  [8.15]
#  [7.36]
#  [8.31]
#  [6.6 ]
#  [6.59]
#  [7.47]
#  [7.93]
#  [6.29]
#  [6.37]
#  [6.47]]

# %%
print("R2",r2_score(y_test,y_pre))
# Out:
# R2 0.7807301475103842
# R2 0.7807301475103842
